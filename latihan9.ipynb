# %% [markdown]
# <a href="https://colab.research.google.com/github/hisyamabdulah/Pemerograman-dasar/blob/main/latihan9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
importimport pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/customers.csv', sep=';')

# %%
rata_rata_umur = df['age'].mean()
print("Rata-rata umur (age):", rata_rata_umur)


modus_gender = df['gender'].mode()
print("Modus gender:", modus_gender.iloc[0])
# Out:
# Rata-rata umur (age): 50.92949354518371
# Modus gender: Prefer not to say

# %%
import matplotlib.pyplot as plt
mean_age.plot(kind='bar')

plt.title("Rata-rata Umur Customer Setiap Gender")
plt.xlabel("Gender")
plt.ylabel("Umur")
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
# Korelasi
corr_matrix = df[['age']].corr()
print("Korelasi:", corr_matrix)

# Kovarian
cov_matrix = df[['age']].cov()
print("Kovarian:", cov_matrix)
# Out:
# Korelasi:      age
# age  1.0
# Kovarian:             age
# age  931.244527

# %%
# Menambah kolom kategori
df['Kategori_umur'] = df['age'].apply(lambda x: 'Banyak' if x >= 3 else 'Sedikit')
df

# Rata-rata umur per kategori
group_mean = df.groupby('Kategori_umur')['age'].mean()
print(group_mean)

# Agregasi lengkap
group_agg = df.groupby('Kategori_umur').agg({
    'age': ['mean', 'max'],
    'age': ['mean', 'count']
})
group_agg
# Out:
# Kategori_umur
# Banyak    50.929494
# Name: age, dtype: float64
#                      age
#                     mean count
# Kategori_umur
# Banyak         50.929494  1007
